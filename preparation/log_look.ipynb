# %% [markdown]
# I need to parse through .log files to collate information on the status of compounds.

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.DataStructs import TanimotoSimilarity

def parse_log_file(log_file_path):
    # List to hold the relevant log lines
    log_entries = []

    # Keywords for filtering the log lines
    error_keywords = ['ERROR']
    info_keywords = ['INFO', 'successful placements', 'Saved HIPPO', 'Finished elaborating']

    # Open and read the log file line by line
    with open(log_file_path, 'r') as log_file:
        for line in log_file:
            # Filter for ERROR lines
            if any(keyword in line for keyword in error_keywords):
                log_entries.append(line.strip())
            # Filter for WARNING lines, excluding those from 'syndirella.slipper.intra_geometry'
            elif 'WARNING' in line and 'syndirella.slipper.intra_geometry' not in line and 'matplotlib' not in line:
                log_entries.append(line.strip())
            # Filter for INFO lines that meet the criteria
            elif 'INFO' in line and (
                    'successful placements' in line or
                    'Saved HIPPO' in line or
                    'Finished elaborating' in line or
                    'Placing' in line or
                    'Running retrosynthesis' in line or
                    'Elaborating compound' in line):
                log_entries.append(line.strip())

    # Create a DataFrame from the filtered log lines
    log_df = pd.DataFrame(log_entries, columns=['LogEntry'])

    return log_df

# %%
log_file_path = '../logs/slurm-error_Ax0926a_manual_70033.log'
df = parse_log_file(log_file_path)
df
# Out:
#                                             LogEntry
# 0  2024-08-06 16:57:45,954 - syndirella.pipeline ...
# 1  2024-08-06 17:05:39,490 - syndirella.slipper.S...
# 2  2024-08-07 01:16:53,268 - syndirella.slipper.S...
# 3  2024-08-07 01:22:51,564 - syndirella.slipper.S...
# 4  2024-08-07 01:22:54,391 - syndirella.slipper.S...
# 5  2024-08-07 01:23:18,987 - syndirella.pipeline ...

# %%
log_file_path = '../logs/slurm-error_A71EV2A_exact_hits_3_71665.log'
df = parse_log_file(log_file_path)
df
# Out:
#                                              LogEntry
# 0   2024-08-07 13:48:34,477 - syndirella.Cobbler.C...
# 1   2024-08-07 13:57:36,023 - syndirella.slipper.S...
# 2   2024-08-07 16:51:31,190 - syndirella.slipper.S...
# 3   2024-08-07 16:54:12,906 - syndirella.slipper.S...
# 4   2024-08-07 16:54:13,393 - syndirella.slipper.S...
# 5   2024-08-07 16:54:21,097 - syndirella.pipeline ...
# 6   2024-08-07 16:54:24,498 - syndirella.Cobbler.C...
# 7   2024-08-07 16:58:37,670 - syndirella.slipper.S...
# 8   2024-08-07 17:41:32,880 - syndirella.slipper.S...
# 9   2024-08-07 17:42:12,523 - syndirella.slipper.S...
# 10  2024-08-07 17:42:12,659 - syndirella.slipper.S...
# 11  2024-08-07 17:42:14,445 - syndirella.pipeline ...
# 12  2024-08-07 17:42:16,598 - syndirella.Cobbler.C...
# 13  2024-08-07 17:51:35,125 - syndirella.slipper.S...
# 14  2024-08-07 18:55:40,095 - syndirella.slipper.S...
# 15  2024-08-07 18:56:14,813 - syndirella.slipper.S...
# 16  2024-08-07 18:56:15,009 - syndirella.slipper.S...
# 17  2024-08-07 18:56:16,676 - syndirella.pipeline ...

# %%
log_file_path = '../logs/slurm-error_A71EV2A_ryan_merges_24_71338.log'
df = parse_log_file(log_file_path)
df
# Out:
#                                              LogEntry
# 0   2024-08-07 11:06:09,815 - syndirella.pipeline ...
# 1   2024-08-07 11:06:09,815 - syndirella.pipeline ...
# 2   2024-08-07 11:06:13,959 - syndirella.Cobbler.C...
# 3   2024-08-07 11:10:56,667 - syndirella.slipper.S...
# 4   2024-08-07 13:14:05,510 - syndirella.slipper.S...
# ..                                                ...
# 67  2024-08-08 06:07:26,940 - syndirella.pipeline ...
# 68  2024-08-08 06:07:50,380 - syndirella.pipeline ...
# 69  2024-08-08 06:07:50,380 - syndirella.pipeline ...
# 70  2024-08-08 06:07:56,336 - syndirella.Cobbler.C...
# 71  2024-08-08 06:11:43,611 - syndirella.slipper.S...
#
# [72 rows x 1 columns]

# %%
# adding information to input csv
import re

def tanimoto_similarity(smiles1: str, smiles2: str):
    mol1 = Chem.MolFromSmiles(smiles1)
    mol2 = Chem.MolFromSmiles(smiles2)
    fp1 = AllChem.GetMorganFingerprintAsBitVect(mol1, radius=2, nBits=2048)
    fp2 = AllChem.GetMorganFingerprintAsBitVect(mol2, radius=2, nBits=2048)
    return TanimotoSimilarity(fp1, fp2)

def output_info(smiles: str, log_df: pd.DataFrame) -> dict:
    pattern = re.compile(re.escape(smiles))
    # get beginning index of row that contain smiles
    try:
        smiles_index = log_df[log_df['LogEntry'].str.contains(pattern)].index[0]
    except IndexError:
        return {'smiles': smiles,
                'output': 'not-found'}
    # get last index of row that contain smiles
    smiles_index_end = log_df[log_df['LogEntry'].str.contains(pattern)].index[-1]
    for row in log_df.loc[smiles_index:smiles_index_end, 'LogEntry']:
        if 'could not be placed successfully. Skipping...' in row:
            return {'smiles': smiles,
                    'output': 'base-failed'}
        elif 'Saved HIPPO' in row:
            return {'smiles': smiles,
                    'output': 'successful'}
        elif 'There are no final routes' in row:
            return {'smiles': smiles,
                    'output': 'no-synthesis-routes'}
        elif 'Error elaborating compound' in row:
            return {'smiles': smiles,
                    'output': 'general-error'}
        elif 'Could not get the final library' in row:
            return {'smiles': smiles,
                    'output': 'SMARTS-error'}
    return {'smiles': smiles,
            'output': 'not-found'}
    
def add_output(input_file_path: str, log_file_path: str):
    # get list of smiles from input_file_path
    input_df = pd.read_csv(input_file_path)
    input_smiles = input_df['smiles'].tolist()
    # get log_df
    log_df = parse_log_file(log_file_path)
    # for each smiles, need to get log output
    outputs = []
    for smiles in input_smiles:
        output = output_info(smiles, log_df)
        outputs.append(output)
    output_df = pd.DataFrame(outputs)
    input_df = input_df.merge(output_df, on='smiles', how='left')
    if 'Unnamed: 0' in input_df.columns:
        input_df = input_df.drop(columns=['Unnamed: 0'])
    if 'Unnamed: 4' in input_df.columns:
        input_df = input_df.drop(columns=['Unnamed: 4'])
    # add date_collected column
    input_df['date_collected'] = pd.to_datetime('today').strftime('%Y-%m-%d')
    return input_df

# %%
output_info('CC(=O)Nc1c(C(C)CS(=O)(=O)NCC2CCCC2)cnnc1F', df)
# Out:
# {'smiles': 'CC(=O)Nc1c(C(C)CS(=O)(=O)NCC2CCCC2)cnnc1F', 'output': 'not-found'}

# %%
df = add_output('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_input/molecule-set-A71_2A_ryan_merges_24.csv', 
           '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/logs/slurm-error_A71EV2A_ryan_merges_24_71338.log')
df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_2A_ryan_merges_24.csv', index=False)

# %%
df = add_output('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_input/molecule-set-A71_EV_2A_exact_hits_3.csv',
              '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/logs/slurm-error_A71EV2A_exact_hits_3_71665.log')
df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_EV_2A_exact_hits_3.csv', index=False)

# %%
df = add_output('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_input/molecule-set-A71_EV_2A_Ax0926a_manual.csv',
              '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/logs/slurm-error_Ax0926a_manual_70033.log')
df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_EV_2A_Ax0926a_manual.csv', index=False)

# %%
df = add_output('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_input/molecule-set-A71_EV_2A_covalent_and_noncovalents_16.csv',
                '../logs/slurm-error_A71EV2A_covalent_noncovalents_16_71339.log')
df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_EV_2A_covalent_and_noncovalents_16.csv', index=False)

# %%
df = add_output('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_input/A71EV2A_Knitwork_June_42.csv',
                '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/logs/slurm-error_A71EV2A_Knitwork_71641.log')
df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/A71EV2A_Knitwork_June_42.csv', index=False)
df
# Out:
#                                            smiles template  \
# 0                      N#CCC(=O)Nc1ccc(C(N)=O)nc1  Ax0310a
# 1                  CC(=O)Nc1ccc(NCc2ccc(F)cc2)nc1  Ax0310a
# 2                 COc1cccc(CNc2ccc(NC(C)=O)cn2)c1  Ax0310a
# 3                 CC(=O)Nc1ccc(NCc2ccc(C)cc2F)nc1  Ax0310a
# 4              CC(=O)Nc1ccc(NCc2cccc(C(C)C)c2)nc1  Ax0310a
# 5                    Cn1nc(C2CCCOC2)cc1NC(=O)CC#N  Ax0310a
# 6                 CC(=O)Nc1ccc(NCc2cc(F)ccc2C)nc1  Ax0310a
# 7                CC(=O)Nc1ccc(NCc2ccccc2C2CC2)nc1  Ax0310a
# 8                 CC(=O)Nc1ccc(NCc2c(C)cccc2F)nc1  Ax0310a
# 9                      Cn1ccc2ccc(NCc3ccccc3)cc21  Ax0310a
# 10           Cc1ccc(CNc2ccc(N3CCNC(=O)C3)cn2)cc1C  Ax0310a
# 11             O=C1NCCC1C(=O)N1CCCC(NCc2ccccc2)C1  Ax0310a
# 12        O=C1NCCN1c1ccc(NCc2ccc(C(F)(F)F)cc2)cc1  Ax0310a
# 13               O=C1NCCN1c1ccc(NCc2cccc(F)c2)cc1  Ax0310a
# 14           CSc1cccc(CNc2ccc(N3CCNC(=O)C3)cn2)c1  Ax0310a
# 15           Cn1nc(C2CCOCC2)cc1C(=O)OCC1CNC(=O)C1  Ax0310a
# 16             NCc1ccc(C(=O)Nc2c[nH]c3ccccc23)cc1  Ax0310a
# 17           Cc1ncc(C(=O)N(C)C2CN(C3CCNC3=O)C2)s1  Ax0310a
# 18              CCC(C)CC(=O)Nc1ccc(C(=O)N(C)C)cc1  Ax0310a
# 19  CN(C)C(=O)c1ccc(NC(=O)CC(C)(C)C(F)(F)F)c(F)c1  Ax0310a
# 20                  COc1cncc(CCC(=O)NC2CCNC2=O)c1  Ax0310a
# 21                     O=C(OCC1CCCNC1=O)c1ccncc1F  Ax0310a
# 22                 CN1CCC(c2nc(-c3ccncc3)no2)C1=O  Ax0310a
# 23       CCC1CC(NC(=O)c2ccc(NC(=O)C(C)(C)C)nc2)C1  Ax0310a
# 24                 CCOC(=O)c1cc(NC(=O)CC#N)n(C)n1  Ax0310a
# 25    CC(C)(C)C(=O)Nc1ccc(C(=O)NC2(C(F)F)CCC2)cn1  Ax0310a
# 26          CCCC(=O)NC1CCN(C(=O)NC2CC(CC#N)C2)CC1  Ax0310a
# 27          NC(=O)c1cc(NC(=O)C23CCC(CO2)C3)[nH]n1  Ax0310a
# 28          O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Ax0310a
# 29      CC(C)(C)OC1CC(NC(=O)N2CCCC2CS(N)(=O)=O)C1  Ax0310a
# 30        N#CCC1CC(NC(=O)N2CCCC(CS(N)(=O)=O)C2)C1  Ax0310a
# 31      NS(=O)(=O)CC1CCCCN1C(=O)NC1(C(F)(F)F)CCC1  Ax0310a
# 32       Cn1cc(C(O)C(=O)Nc2cccc(NC(=O)CC#N)c2)cn1  Ax0310a
# 33            CC1(NC(=O)Nc2ccccc2CS(N)(=O)=O)CCC1  Ax0310a
# 34                   CC(=O)Nc1ccc(NCc2ccccc2F)cn1  Ax0310a
# 35          CC(=O)N(C)c1ccc(NCc2cccc(C(C)C)c2)cn1  Ax0310a
# 36                   CC(=O)Nc1ccc(NCc2ccccc2C)cn1  Ax0310a
# 37           CC(=O)N(C)c1ccc(NCc2ccccc2C2CC2)cn1   Ax0310a
# 38      Cc1ccc(C(=O)Nc2ccc(N3CCNC(=O)C3)nc2)cc1C   Ax0310a
# 39        O=C1CCCN1c1ccc(NCc2ccc(C(F)(F)F)cc2)nc1  Ax0310a
# 40               O=C1CCCN1c1ccc(NCc2cccc(F)c2)nc1  Ax0310a
# 41                    CC(=O)Nc1ccc(C(=O)N(C)C)nc1  Ax0310a
#
#                                                  hits  \
# 0   A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 1   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 2   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 3   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 4   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 5   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 6   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 7   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 8   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 9   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+9 A7...
# 10  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+10 A...
# 11  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+10 A...
# 12  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+10 A...
# 13  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+10 A...
# 14  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+10 A...
# 15  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+10 A...
# 16  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+16 A...
# 17  A71EV2A-x0446_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 18  A71EV2A-x0450_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 19  A71EV2A-x0450_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 20  A71EV2A-x0515_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 21  A71EV2A-x0515_A_201_1_A71EV2A-x0526+A+147+2 A7...
# 22  A71EV2A-x0528_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 23  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 24  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 25  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 26  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 27  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+5 A7...
# 28  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+6 A7...
# 29  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+7 A7...
# 30  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+7 A7...
# 31  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+7 A7...
# 32  A71EV2A-x0732_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 33  A71EV2A-x0884_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 34  A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 35  A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+2 A7...
# 36  A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+3 A7...
# 37  A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+4 A7...
# 38  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+16 A...
# 39  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+17 A...
# 40  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+18 A...
# 41  A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+1 A7...
#
#                    compound_set       short_hits         output date_collected
# 0            knitwork_june_2024  Ax0310a Ax0556a     successful     2024-08-14
# 1            knitwork_june_2025  Ax0365a Ax0310a  general-error     2024-08-14
# 2            knitwork_june_2026  Ax0365a Ax0310a     successful     2024-08-14
# 3            knitwork_june_2027  Ax0365a Ax0310a  general-error     2024-08-14
# 4            knitwork_june_2028  Ax0365a Ax0310a  general-error     2024-08-14
# 5            knitwork_june_2029  Ax0365a Ax0310a     successful     2024-08-14
# 6            knitwork_june_2030  Ax0365a Ax0310a  general-error     2024-08-14
# 7            knitwork_june_2031  Ax0365a Ax0310a  general-error     2024-08-14
# 8            knitwork_june_2032  Ax0365a Ax0310a  general-error     2024-08-14
# 9            knitwork_june_2033  Ax0365a Ax0451a     successful     2024-08-14
# 10           knitwork_june_2034  Ax0365a Ax0528a    base-failed     2024-08-14
# 11           knitwork_june_2035  Ax0365a Ax0528a    base-failed     2024-08-14
# 12           knitwork_june_2036  Ax0365a Ax0528a    base-failed     2024-08-14
# 13           knitwork_june_2037  Ax0365a Ax0528a    base-failed     2024-08-14
# 14           knitwork_june_2038  Ax0365a Ax0528a    base-failed     2024-08-14
# 15           knitwork_june_2039  Ax0365a Ax0528a    base-failed     2024-08-14
# 16           knitwork_june_2040  Ax0365a Ax0566a     successful     2024-08-14
# 17           knitwork_june_2041  Ax0446a Ax0528a     successful     2024-08-14
# 18           knitwork_june_2042  Ax0450a Ax0310a     successful     2024-08-14
# 19           knitwork_june_2043  Ax0450a Ax0310a     successful     2024-08-14
# 20           knitwork_june_2044  Ax0515a Ax0528a     successful     2024-08-14
# 21           knitwork_june_2045  Ax0515a Ax0528a    base-failed     2024-08-14
# 22           knitwork_june_2046  Ax0528a Ax0515a    base-failed     2024-08-14
# 23           knitwork_june_2047  Ax0556a Ax0310a     successful     2024-08-14
# 24           knitwork_june_2048  Ax0556a Ax0310a     successful     2024-08-14
# 25           knitwork_june_2049  Ax0556a Ax0310a     successful     2024-08-14
# 26           knitwork_june_2050  Ax0556a Ax0310a   SMARTS-error     2024-08-14
# 27           knitwork_june_2051  Ax0556a Ax0528a     successful     2024-08-14
# 28           knitwork_june_2052  Ax0556a Ax0566a     successful     2024-08-14
# 29           knitwork_june_2053  Ax0556a Ax0719a    base-failed     2024-08-14
# 30           knitwork_june_2054  Ax0556a Ax0719a    base-failed     2024-08-14
# 31           knitwork_june_2055  Ax0556a Ax0719a    base-failed     2024-08-14
# 32           knitwork_june_2056  Ax0732a Ax0310a     successful     2024-08-14
# 33           knitwork_june_2057  Ax0884a Ax0719a   SMARTS-error     2024-08-14
# 34  modified_knitwork_june_2024  Ax0310a Ax0365a  general-error     2024-08-14
# 35  modified_knitwork_june_2025  Ax0310a Ax0365a      not-found     2024-08-14
# 36  modified_knitwork_june_2026  Ax0310a Ax0365a      not-found     2024-08-14
# 37  modified_knitwork_june_2027  Ax0310a Ax0365a      not-found     2024-08-14
# 38  modified_knitwork_june_2028  Ax0365a Ax0528a      not-found     2024-08-14
# 39  modified_knitwork_june_2029  Ax0365a Ax0528a      not-found     2024-08-14
# 40  modified_knitwork_june_2030  Ax0365a Ax0528a      not-found     2024-08-14
# 41  modified_knitwork_june_2031  Ax0310a Ax0450a      not-found     2024-08-14

# %%
df = add_output('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_input/molecule-set-aug_2024_x1346_analogues_38.csv','/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/logs/slurm-error_A71EV2A_x1346_analogues_38_71603.log')
df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-aug_2024_x1346_analogues_38.csv', index=False)

# %%
# make master df with all outputs as columns and rows as the csv name
ryan = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_2A_ryan_merges_24.csv')
exact = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_EV_2A_exact_hits_3.csv')
manual = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_EV_2A_Ax0926a_manual.csv')
covalent = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_EV_2A_covalent_and_noncovalents_16.csv')
knitwork = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/A71EV2A_Knitwork_June_42.csv')
x1346 = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-aug_2024_x1346_analogues_38.csv')

master_dfs = [ryan, exact, manual, covalent, knitwork, x1346]
names = ['ryan', 'exact', 'manual_exact', 'covalents', 'knitwork', 'x1346_analogues']

master = []
for df, name in zip(master_dfs, names):
    df = df.value_counts('output')
    print(df)
    # get the number of successful, base-failed, no-synthesis-routes, general-error if they exist
    to_add = {'name': name,
              'successful': df.get('successful', 0),
              'base-failed': df.get('base-failed', 0),
              'no-synthesis-routes': df.get('no-synthesis-routes', 0),
              'general-error': df.get('general-error', 0),
              'not-found': df.get('not-found', 0)}
    master.append(to_add)

master_df = pd.DataFrame(master)
# Out:
# output
# base-failed            9
# no-synthesis-routes    8
# general-error          4
# successful             3
# not-found              2
# Name: count, dtype: int64
# output
# successful    3
# Name: count, dtype: int64
# output
# successful    1
# Name: count, dtype: int64
# output
# successful       11
# SMARTS-error      4
# general-error     1
# Name: count, dtype: int64
# output
# successful       15
# base-failed      11
# general-error     7
# not-found         7
# SMARTS-error      2
# Name: count, dtype: int64
# output
# SMARTS-error     13
# not-found        10
# general-error     8
# successful        5
# base-failed       2
# Name: count, dtype: int64

# %%
master_df
# Out:
#               name  successful  base-failed  no-synthesis-routes  \
# 0             ryan           3            9                    8
# 1            exact           3            0                    0
# 2     manual_exact           1            0                    0
# 3        covalents          11            0                    0
# 4         knitwork          15           11                    0
# 5  x1346_analogues           5            2                    0
#
#    general-error  not-found
# 0              4          2
# 1              0          0
# 2              0          0
# 3              1          0
# 4              7          7
# 5              8         10

# %%
master_df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/master_output.csv', index=False)

# %%
master_df = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/master_output.csv')
# add total row at end of each column
total = master_df.sum()
total['name'] = 'total'
master_df = pd.concat([master_df, total.to_frame().T])
master_df
# Out:
#               name successful base-failed no-synthesis-routes general-error  \
# 0             ryan          3           9                   8             4
# 1            exact          3           0                   0             0
# 2     manual_exact          1           0                   0             0
# 3        covalents         11           0                   0             1
# 4         knitwork         15          11                   0             7
# 5  x1346_analogues          5           2                   0             8
# 0            total         38          22                   8            20
#
#   not-found
# 0         2
# 1         0
# 2         0
# 3         0
# 4         7
# 5        10
# 0        19

# %%
# get all columns except name
cols = master_df.columns[1:]
# get total per row
master_df['total'] = master_df[cols].sum(axis=1)
master_df
# Out:
#               name successful base-failed no-synthesis-routes general-error  \
# 0             ryan          3           9                   8             4
# 1            exact          3           0                   0             0
# 2     manual_exact          1           0                   0             0
# 3        covalents         11           0                   0             1
# 4         knitwork         15          11                   0             7
# 5  x1346_analogues          5           2                   0             8
# 0            total         38          22                   8            20
#
#   not-found total
# 0         2    26
# 1         0     3
# 2         0     1
# 3         0    12
# 4         7    40
# 5        10    25
# 0        19   107

# %%
master_df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/master_output.csv', index=False)

# %% [markdown]
# # Aug 14 – What are the common errors that I need to fix?

# %%
# knitwork_redone
df = add_output('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_input/A71EV2A_Knitwork_June_9_redone.csv',
                '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/logs/slurm-error_Knitwork_June_9_redone_73011.log')
df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/A71EV2A_Knitwork_June_9_redone.csv', index=False)

# %%
# x1346_analogues
df = add_output('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_input/molecule-set-aug_2024_x1346_analogues_38.csv',
                '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/logs/slurm-error_A71EV2A_x1346_analogues_38_71603.log')
df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-aug_2024_x1346_analogues_38.csv', index=False)

# %%
# knitwork_1st
df = add_output('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_input/A71EV2A_Knitwork_June_42.csv',
                '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/logs/slurm-error_A71EV2A_Knitwork_71641.log')
df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/A71EV2A_Knitwork_June_42.csv', index=False)

# %%
# get dataframe of old knitwork and redone merged
knitwork = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/A71EV2A_Knitwork_June_42.csv')
knitwork_redone = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/A71EV2A_Knitwork_June_9_redone.csv')
knitwork = pd.concat([knitwork, knitwork_redone])
# drop duplicates, keep last
knitwork = knitwork.drop_duplicates(subset=['smiles'], keep='last')
knitwork
# Out:
#                                            smiles template  \
# 0                      N#CCC(=O)Nc1ccc(C(N)=O)nc1  Ax0310a
# 1                  CC(=O)Nc1ccc(NCc2ccc(F)cc2)nc1  Ax0310a
# 2                 COc1cccc(CNc2ccc(NC(C)=O)cn2)c1  Ax0310a
# 3                 CC(=O)Nc1ccc(NCc2ccc(C)cc2F)nc1  Ax0310a
# 4              CC(=O)Nc1ccc(NCc2cccc(C(C)C)c2)nc1  Ax0310a
# 5                    Cn1nc(C2CCCOC2)cc1NC(=O)CC#N  Ax0310a
# 6                 CC(=O)Nc1ccc(NCc2cc(F)ccc2C)nc1  Ax0310a
# 7                CC(=O)Nc1ccc(NCc2ccccc2C2CC2)nc1  Ax0310a
# 8                 CC(=O)Nc1ccc(NCc2c(C)cccc2F)nc1  Ax0310a
# 9                      Cn1ccc2ccc(NCc3ccccc3)cc21  Ax0310a
# 16             NCc1ccc(C(=O)Nc2c[nH]c3ccccc23)cc1  Ax0310a
# 17           Cc1ncc(C(=O)N(C)C2CN(C3CCNC3=O)C2)s1  Ax0310a
# 18              CCC(C)CC(=O)Nc1ccc(C(=O)N(C)C)cc1  Ax0310a
# 19  CN(C)C(=O)c1ccc(NC(=O)CC(C)(C)C(F)(F)F)c(F)c1  Ax0310a
# 20                  COc1cncc(CCC(=O)NC2CCNC2=O)c1  Ax0310a
# 21                     O=C(OCC1CCCNC1=O)c1ccncc1F  Ax0310a
# 22                 CN1CCC(c2nc(-c3ccncc3)no2)C1=O  Ax0310a
# 23       CCC1CC(NC(=O)c2ccc(NC(=O)C(C)(C)C)nc2)C1  Ax0310a
# 24                 CCOC(=O)c1cc(NC(=O)CC#N)n(C)n1  Ax0310a
# 25    CC(C)(C)C(=O)Nc1ccc(C(=O)NC2(C(F)F)CCC2)cn1  Ax0310a
# 26          CCCC(=O)NC1CCN(C(=O)NC2CC(CC#N)C2)CC1  Ax0310a
# 27          NC(=O)c1cc(NC(=O)C23CCC(CO2)C3)[nH]n1  Ax0310a
# 28          O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Ax0310a
# 32       Cn1cc(C(O)C(=O)Nc2cccc(NC(=O)CC#N)c2)cn1  Ax0310a
# 33            CC1(NC(=O)Nc2ccccc2CS(N)(=O)=O)CCC1  Ax0310a
# 34                   CC(=O)Nc1ccc(NCc2ccccc2F)cn1  Ax0310a
# 35          CC(=O)N(C)c1ccc(NCc2cccc(C(C)C)c2)cn1  Ax0310a
# 36                   CC(=O)Nc1ccc(NCc2ccccc2C)cn1  Ax0310a
# 37           CC(=O)N(C)c1ccc(NCc2ccccc2C2CC2)cn1   Ax0310a
# 38      Cc1ccc(C(=O)Nc2ccc(N3CCNC(=O)C3)nc2)cc1C   Ax0310a
# 39        O=C1CCCN1c1ccc(NCc2ccc(C(F)(F)F)cc2)nc1  Ax0310a
# 40               O=C1CCCN1c1ccc(NCc2cccc(F)c2)nc1  Ax0310a
# 41                    CC(=O)Nc1ccc(C(=O)N(C)C)nc1  Ax0310a
# 0            Cc1ccc(CNc2ccc(N3CCNC(=O)C3)cn2)cc1C  Ax0310a
# 1              O=C1NCCC1C(=O)N1CCCC(NCc2ccccc2)C1  Ax0310a
# 2         O=C1NCCN1c1ccc(NCc2ccc(C(F)(F)F)cc2)cc1  Ax0310a
# 3                O=C1NCCN1c1ccc(NCc2cccc(F)c2)cc1  Ax0310a
# 4            CSc1cccc(CNc2ccc(N3CCNC(=O)C3)cn2)c1  Ax0310a
# 5            Cn1nc(C2CCOCC2)cc1C(=O)OCC1CNC(=O)C1  Ax0310a
# 6       CC(C)(C)OC1CC(NC(=O)N2CCCC2CS(N)(=O)=O)C1  Ax0310a
# 7         N#CCC1CC(NC(=O)N2CCCC(CS(N)(=O)=O)C2)C1  Ax0310a
# 8       NS(=O)(=O)CC1CCCCN1C(=O)NC1(C(F)(F)F)CCC1  Ax0310a
#
#                                                  hits  \
# 0   A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 1   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 2   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 3   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 4   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 5   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 6   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 7   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 8   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 9   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+9 A7...
# 16  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+16 A...
# 17  A71EV2A-x0446_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 18  A71EV2A-x0450_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 19  A71EV2A-x0450_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 20  A71EV2A-x0515_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 21  A71EV2A-x0515_A_201_1_A71EV2A-x0526+A+147+2 A7...
# 22  A71EV2A-x0528_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 23  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 24  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 25  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 26  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 27  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+5 A7...
# 28  A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+6 A7...
# 32  A71EV2A-x0732_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 33  A71EV2A-x0884_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 34  A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 35  A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+2 A7...
# 36  A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+3 A7...
# 37  A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+4 A7...
# 38  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+16 A...
# 39  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+17 A...
# 40  A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+18 A...
# 41  A71EV2A-x0310_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 0   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 1   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 2   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 3   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 4   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 5   A71EV2A-x0365_A_201_1_A71EV2A-x0526+A+147+1 A7...
# 6   A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 7   A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
# 8   A71EV2A-x0556_A_147_1_A71EV2A-x0526+A+147+1 A7...
#
#                    compound_set       short_hits         output date_collected
# 0            knitwork_june_2024  Ax0310a Ax0556a     successful     2024-08-14
# 1            knitwork_june_2025  Ax0365a Ax0310a  general-error     2024-08-14
# 2            knitwork_june_2026  Ax0365a Ax0310a     successful     2024-08-14
# 3            knitwork_june_2027  Ax0365a Ax0310a  general-error     2024-08-14
# 4            knitwork_june_2028  Ax0365a Ax0310a  general-error     2024-08-14
# 5            knitwork_june_2029  Ax0365a Ax0310a     successful     2024-08-14
# 6            knitwork_june_2030  Ax0365a Ax0310a  general-error     2024-08-14
# 7            knitwork_june_2031  Ax0365a Ax0310a  general-error     2024-08-14
# 8            knitwork_june_2032  Ax0365a Ax0310a  general-error     2024-08-14
# 9            knitwork_june_2033  Ax0365a Ax0451a     successful     2024-08-14
# 16           knitwork_june_2040  Ax0365a Ax0566a     successful     2024-08-14
# 17           knitwork_june_2041  Ax0446a Ax0528a     successful     2024-08-14
# 18           knitwork_june_2042  Ax0450a Ax0310a     successful     2024-08-14
# 19           knitwork_june_2043  Ax0450a Ax0310a     successful     2024-08-14
# 20           knitwork_june_2044  Ax0515a Ax0528a     successful     2024-08-14
# 21           knitwork_june_2045  Ax0515a Ax0528a    base-failed     2024-08-14
# 22           knitwork_june_2046  Ax0528a Ax0515a    base-failed     2024-08-14
# 23           knitwork_june_2047  Ax0556a Ax0310a     successful     2024-08-14
# 24           knitwork_june_2048  Ax0556a Ax0310a     successful     2024-08-14
# 25           knitwork_june_2049  Ax0556a Ax0310a     successful     2024-08-14
# 26           knitwork_june_2050  Ax0556a Ax0310a   SMARTS-error     2024-08-14
# 27           knitwork_june_2051  Ax0556a Ax0528a     successful     2024-08-14
# 28           knitwork_june_2052  Ax0556a Ax0566a     successful     2024-08-14
# 32           knitwork_june_2056  Ax0732a Ax0310a     successful     2024-08-14
# 33           knitwork_june_2057  Ax0884a Ax0719a   SMARTS-error     2024-08-14
# 34  modified_knitwork_june_2024  Ax0310a Ax0365a  general-error     2024-08-14
# 35  modified_knitwork_june_2025  Ax0310a Ax0365a      not-found     2024-08-14
# 36  modified_knitwork_june_2026  Ax0310a Ax0365a      not-found     2024-08-14
# 37  modified_knitwork_june_2027  Ax0310a Ax0365a      not-found     2024-08-14
# 38  modified_knitwork_june_2028  Ax0365a Ax0528a      not-found     2024-08-14
# 39  modified_knitwork_june_2029  Ax0365a Ax0528a      not-found     2024-08-14
# 40  modified_knitwork_june_2030  Ax0365a Ax0528a      not-found     2024-08-14
# 41  modified_knitwork_june_2031  Ax0310a Ax0450a      not-found     2024-08-14
# 0            knitwork_june_2024  Ax0365a Ax0528a  general-error     2024-08-14
# 1            knitwork_june_2024  Ax0365a Ax0528a     successful     2024-08-14
# 2            knitwork_june_2024  Ax0365a Ax0528a     successful     2024-08-14
# 3            knitwork_june_2024  Ax0365a Ax0528a     successful     2024-08-14
# 4            knitwork_june_2024  Ax0365a Ax0528a  general-error     2024-08-14
# 5            knitwork_june_2024  Ax0365a Ax0528a     successful     2024-08-14
# 6            knitwork_june_2024  Ax0556a Ax0719a   SMARTS-error     2024-08-14
# 7            knitwork_june_2024  Ax0556a Ax0719a   SMARTS-error     2024-08-14
# 8            knitwork_june_2024  Ax0556a Ax0719a   SMARTS-error     2024-08-14

# %%
# make master df with all outputs as columns and rows as the csv name
ryan = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_2A_ryan_merges_24.csv')
exact = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_EV_2A_exact_hits_3.csv')
manual = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_EV_2A_Ax0926a_manual.csv')
covalent = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-A71_EV_2A_covalent_and_noncovalents_16.csv')
x1346 = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/molecule-set-aug_2024_x1346_analogues_38.csv')

master_dfs = [ryan, exact, manual, covalent, knitwork, x1346]
names = ['ryan', 'exact', 'manual_exact', 'covalents', 'knitwork', 'x1346_analogues']

master = []
for df, name in zip(master_dfs, names):
    df = df.value_counts('output')
    print(df)
    # get the number of successful, base-failed, no-synthesis-routes, general-error if they exist
    to_add = {'name': name,
              'successful': df.get('successful', 0),
              'base-failed': df.get('base-failed', 0),
              'no-synthesis-routes': df.get('no-synthesis-routes', 0),
              'general-error': df.get('general-error', 0),
              'SMARTS-error': df.get('SMARTS-error', 0),
              'not-found': df.get('not-found', 0)}
    master.append(to_add)

master_df = pd.DataFrame(master)
# Out:
# output
# base-failed            9
# no-synthesis-routes    8
# general-error          4
# successful             3
# not-found              2
# Name: count, dtype: int64
# output
# successful    3
# Name: count, dtype: int64
# output
# successful    1
# Name: count, dtype: int64
# output
# successful       11
# SMARTS-error      4
# general-error     1
# Name: count, dtype: int64
# output
# successful       19
# general-error     9
# not-found         7
# SMARTS-error      5
# base-failed       2
# Name: count, dtype: int64
# output
# SMARTS-error     13
# not-found        10
# general-error     8
# successful        5
# base-failed       2
# Name: count, dtype: int64

# %%
master_df
# Out:
#               name  successful  base-failed  no-synthesis-routes  \
# 0             ryan           3            9                    8
# 1            exact           3            0                    0
# 2     manual_exact           1            0                    0
# 3        covalents          11            0                    0
# 4         knitwork          19            2                    0
# 5  x1346_analogues           5            2                    0
#
#    general-error  SMARTS-error  not-found
# 0              4             0          2
# 1              0             0          0
# 2              0             0          0
# 3              1             4          0
# 4              9             5          7
# 5              8            13         10

# %%
master_df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run-2/syndirella_output/master_output.csv', index=False)
